# %% [markdown]
# <a href="https://colab.research.google.com/github/cassavetez/seaborn-plotly-course/blob/master/Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQhjctkBScX6-D3qx-OTj38H5LXuqcFZRigxUvu-p33XjBtctz_8xBYgETI8ZBZJteu0UUoM-TCi2_B/pub?output=csv"
df = pd.read_csv(url)
df.head()
# Out:
#                                                   ID  TOTAL  ... 19944 19943
# 0                                         item_count    397  ...     1     1
# 1  fitting_connector_00_extended-horizontal-conne...    422  ...     0     0
# 2  fitting_connector_00_extended-horizontal-dowel...      0  ...     0     0
# 3  fitting_connector_00_extended-horizontal-dowel...    422  ...     0     0
# 4          fitting_connector_00_modular-halfblocking  16960  ...    24    18
#
# [5 rows x 399 columns]

# %%
# Out:
#      <input type="file" id="files-7fddc9dc-375e-4dd7-8848-d14c6b1ca284" name="files[]" multiple disabled />
#      <output id="result-7fddc9dc-375e-4dd7-8848-d14c6b1ca284">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving k098 - k098.csv to k098 - k098.csv
